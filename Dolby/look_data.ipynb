# %%
import pandas as pd
data=pd.read_table("temp_data.txt",sep='|')
data.head()
# Out:
#    condition task   n   avg_acc  se_accuracy
# 0  seqnothis  avg  37  0.378378     0.080830
# 1  seqnothis  spi  37  0.567568     0.082569
# 2  seqnothis   ss  37  0.189189     0.065276
# 3  seqnothis  var  37  0.216216     0.068611
# 4  seqnotnoh  avg  40  0.450000     0.079663

# %%
data.groupby(['task','condition']).mean()
# Out:
#                       n   avg_acc  se_accuracy
# task condition
# avg  seqnothis     37.0  0.378378     0.080830
#      seqnotnoh     40.0  0.450000     0.079663
#      seqtrahis     40.0  0.500000     0.080064
#      seqtranoh     40.0  0.425000     0.079158
#      statstatstat  41.0  0.463415     0.078845
#      synnotnoh     40.0  0.625000     0.077522
#      syntrahis     40.0  0.450000     0.079663
# spi  seqnothis     37.0  0.567568     0.082569
#      seqnotnoh     40.0  0.450000     0.079663
#      seqtrahis     40.0  0.350000     0.076376
#      seqtranoh     40.0  0.500000     0.080064
#      statstatstat  41.0  0.536585     0.078845
#      synnotnoh     40.0  0.700000     0.073380
#      syntrahis     40.0  0.550000     0.079663
# ss   seqnothis     37.0  0.189189     0.065276
#      seqnotnoh     40.0  0.600000     0.078446
#      seqtrahis     40.0  0.175000     0.060843
#      seqtranoh     40.0  0.200000     0.064051
#      statstatstat  41.0  0.317073     0.073576
# ...
